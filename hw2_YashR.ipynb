# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm

# Import data
ffdaily = pd.read_csv('ff6_daily_factors.csv')
ffmonthly = pd.read_csv('ff6_monthly_factors.csv')
factorlist = ['Mkt-RF', 'SMB', 'HML', 'RMW', 'CMA', 'MOM']

# %% [markdown]
# ### Q1 (a)-(f) for all six factors.

# %%
factordaily_res = pd.read_csv('ff6_daily_factors.csv', usecols = [0])

for factor in factorlist:
    factordaily = ffdaily[['date', factor]].copy()
    # Calculate rolling variance
    factordaily['rolling_var_'+factor] = factordaily[factor].rolling(window=22, min_periods=22).var()
    # Calculate factor weight
    targetvol = factordaily['rolling_var_'+factor].mean()
    factordaily['weight_'+factor] = targetvol/factordaily['rolling_var_'+factor]
    # Collapse to Monthly
    factordaily['mdate'] = (factordaily['date']/100).astype(int)
    factordaily = factordaily.drop_duplicates('mdate', keep='last')
    
    factordaily = factordaily[['mdate', 'weight_'+factor, 'rolling_var_'+factor]].copy()
    factordaily = factordaily.rename(columns={'mdate':'date'})
    factordaily_res = pd.merge(factordaily_res, factordaily, on='date', how='right')

# Merge weights
factormonthly = pd.merge(ffmonthly, factordaily_res, on='date', how='left')


for factor in factorlist:
    
    # Calculate factor return
    factormonthly['Ret_'+factor] = factormonthly['weight_'+factor].shift(1)*(factormonthly[factor])
    
    # Is volatility persistent?
    voldf = factormonthly[['date', 'rolling_var_'+factor, factor]].copy()
    voldf['lag_vol'] = voldf['rolling_var_'+factor].shift(1)
    voldf = voldf.dropna()
    modelvol=sm.OLS(voldf['rolling_var_'+factor], sm.add_constant(voldf[['lag_vol']])).fit()
    print(modelvol.summary())
    
    # Does Vol predict factor returns?
    modelvol=sm.OLS(voldf[factor],sm.add_constant(voldf[['lag_vol']])).fit()
    print(modelvol.summary())
    
    # Asset pricing test of the CAPM
    cols = ['Ret_'+factor, factor]
    returndf = factormonthly[cols].copy().dropna()
    model1=sm.OLS(returndf['Ret_'+factor], sm.add_constant(returndf[[factor]])).fit()
    print(model1.summary())
    
    # AP Test FF3
    cols = ['Ret_'+factor, 'Mkt-RF','SMB', 'HML']
    returndf = factormonthly[cols].copy().dropna()
    model2=sm.OLS(returndf['Ret_'+factor],sm.add_constant(returndf[['Mkt-RF','SMB', 'HML']])).fit()
    print(model2.summary())
    
    # AP Test FF5 + MOM
    cols = ['Ret_'+factor, 'Mkt-RF','SMB', 'HML', 'RMW', 'CMA', 'MOM']
    returndf = factormonthly[cols].copy().dropna()
    model3=sm.OLS(returndf['Ret_'+factor],sm.add_constant(returndf[['Mkt-RF','SMB', 'HML', 'RMW', 'CMA', 'MOM']])).fit()
    print(model3.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:     rolling_var_Mkt-RF   R-squared:                       0.287
# Model:                            OLS   Adj. R-squared:                  0.287
# Method:                 Least Squares   F-statistic:                     466.4
# Date:                Sun, 01 Oct 2023   Prob (F-statistic):           3.39e-87
# Time:                        16:31:02   Log-Likelihood:                -2535.5
# No. Observations:                1160   AIC:                             5075.
# Df Residuals:                    1158   BIC:                             5085.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.5418      0.070      7.790      0.000       0.405       0.678
# lag_vol        0.5358      0.025     21.597      0.000       0.487       0.585
# ==============================================================================
# Omnibus:                     1579.968   Durbin-Watson:                   1.979
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           446466.489
# Skew:                           7.318   Prob(JB):                         0.00
# Kurtosis:                      97.990   Cond. No.                         3.16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 Mkt-RF   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.001
# Method:                 Least Squares   F-statistic:                   0.08310
# Date:                Sun, 01 Oct 2023   Prob (F-statistic):              0.773
# Time:                        16:31:02   Log-Likelihood:                -3591.4
# No. Observations:                1160   AIC:                             7187.
# Df Residuals:                    1158   BIC:                             7197.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.6490      0.173      3.755      0.000       0.310       0.988
# lag_vol        0.0178      0.062      0.288      0.773      -0.103       0.139
# ==============================================================================
# Omnibus:                      180.562   Durbin-Watson:                   1.810
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2588.274
# Skew:                           0.138   Prob(JB):                         0.00
# Kurtosis:                      10.313   Cond. No.                         3.16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             Ret_Mkt-RF   R-squared:                       0.368
# Model:                            OLS   Adj. R-squared:                  0.368
# Method:                 Least Squares   F-statistic:                     675.1
# Date:                Sun, 01 Oct 2023   Prob (F-statistic):          1.25e-117
# Time:                        16:31:02   Log-Likelihood:                -4464.1
# No. Observations:                1160   AIC:                             8932.
# Df Residuals:                    1158   BIC:                             8942.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.9393      0.336      2.794      0.005       0.280       1.599
# Mkt-RF         1.6201      0.062     25.982      0.000       1.498       1.742
# ==============================================================================
# Omnibus:                      239.740   Durbin-Watson:                   1.810
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             6545.071
# Skew:                           0.194   Prob(JB):                         0.00
# Kurtosis:                      14.630   Cond. No.                         5.44
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             Ret_Mkt-RF   R-squared:                       0.378
# Model:                            OLS   Adj. R-squared:                  0.376
# Method:                 Least Squares   F-statistic:                     233.8
# Date:                Sun, 01 Oct 2023   Prob (F-statistic):          1.56e-118
# Time:                        16:31:02   Log-Likelihood:                -4455.4
# No. Observations:                1160   AIC:                             8919.
# Df Residuals:                    1156   BIC:                             8939.
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          1.0412      0.335      3.109      0.002       0.384       1.698
# Mkt-RF         1.7010      0.067     25.512      0.000       1.570       1.832
# SMB           -0.1253      0.110     -1.137      0.256      -0.342       0.091
# HML           -0.3770      0.095     -3.949      0.000      -0.564      -0.190
# ==============================================================================
# Omnibus:                      249.583   Durbin-Watson:                   1.830
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             6215.059
# Skew:                           0.331   Prob(JB):                         0.00
# Kurtosis:                      14.320   Cond. No.                         5.70
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             Ret_Mkt-RF   R-squared:                       0.467
# Model:                            OLS   Adj. R-squared:                  0.463
# Method:                 Least Squares   F-statistic:                     103.8
# Date:                Sun, 01 Oct 2023   Prob (F-statistic):           1.17e-93
# Time:                        16:31:02   Log-Likelihood:                -2604.9
# No. Observations:                 717   AIC:                             5224.
# Df Residuals:                     710   BIC:                             5256.
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0961      0.365      0.264      0.792      -0.620       0.812
# Mkt-RF         1.9768      0.087     22.760      0.000       1.806       2.147
# SMB            0.0643      0.129      0.500      0.617      -0.188       0.317
# HML            0.1978      0.165      1.197      0.232      -0.127       0.522
# RMW            0.3376      0.174      1.943      0.052      -0.004       0.679
# CMA            0.0196      0.247      0.079      0.937      -0.465       0.504
# MOM            0.3934      0.086      4.583      0.000       0.225       0.562
# ==============================================================================
# Omnibus:                      364.434   Durbin-Watson:                   1.942
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             8404.681
# Skew:                           1.761   Prob(JB):                         0.00
# Kurtosis:                      19.399   Cond. No.                         5.38
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        rolling_var_SMB   R-squared:                       0.335
# Model:                            OLS   Adj. R-squared:                  0.334
# Method:                 Least Squares   F-statistic:                     582.8
# Date:                Sun, 01 Oct 2023   Prob (F-statistic):          1.25e-104
# Time:                        16:31:02   Log-Likelihood:                -1056.4
# No. Observations:                1160   AIC:                             2117.
# Df Residuals:                    1158   BIC:                             2127.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.1433      0.019      7.362      0.000       0.105       0.181
# lag_vol        0.5786      0.024     24.142      0.000       0.532       0.626
# ==============================================================================
# Omnibus:                     1462.390   Durbin-Watson:                   2.229
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           395362.445
# Skew:                           6.294   Prob(JB):                         0.00
# Kurtosis:                      92.563   Cond. No.                         1.64
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    SMB   R-squared:                       0.001
# Model:                            OLS   Adj. R-squared:                 -0.000
# Method:                 Least Squares   F-statistic:                    0.8629
# Date:                Sun, 01 Oct 2023   Prob (F-statistic):              0.353
# Time:                        16:31:02   Log-Likelihood:                -2984.6
# No. Observations:                1160   AIC:                             5973.
# Df Residuals:                    1158   BIC:                             5983.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.1518      0.103      1.480      0.139      -0.049       0.353
# lag_vol        0.1174      0.126      0.929      0.353      -0.131       0.365
# ==============================================================================
# Omnibus:                      592.135   Durbin-Watson:                   1.875
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            16549.102
# Skew:                           1.780   Prob(JB):                         0.00
# Kurtosis:                      21.158   Cond. No.                         1.64
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                Ret_SMB   R-squared:                       0.376
# Model:                            OLS   Adj. R-squared:                  0.375
# Method:                 Least Squares   F-statistic:                     696.5
# Date:                Sun, 01 Oct 2023   Prob (F-statistic):          1.45e-120
# Time:                        16:31:02   Log-Likelihood:                -4052.3
# No. Observations:                1160   AIC:                             8109.
# Df Residuals:                    1158   BIC:                             8119.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.1289      0.234     -0.550      0.582      -0.589       0.331
# SMB            1.9462      0.074     26.392      0.000       1.802       2.091
# ==============================================================================
# Omnibus:                      377.547   Durbin-Watson:                   1.624
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            18967.618
# Skew:                          -0.702   Prob(JB):                         0.00
# Kurtosis:                      22.760   Cond. No.                         3.18
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                Ret_SMB   R-squared:                       0.377
# Model:                            OLS   Adj. R-squared:                  0.375
# Method:                 Least Squares   F-statistic:                     233.1
# Date:                Sun, 01 Oct 2023   Prob (F-statistic):          2.90e-118
# Time:                        16:31:02   Log-Likelihood:                -4051.0
# No. Observations:                1160   AIC:                             8110.
# Df Residuals:                    1156   BIC:                             8130.
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0801      0.236     -0.339      0.735      -0.544       0.384
# Mkt-RF        -0.0573      0.047     -1.217      0.224      -0.150       0.035
# SMB            1.9832      0.078     25.499      0.000       1.831       2.136
# HML           -0.0502      0.067     -0.745      0.457      -0.182       0.082
# ==============================================================================
# Omnibus:                      367.748   Durbin-Watson:                   1.634
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            18781.626
# Skew:                          -0.653   Prob(JB):                         0.00
# Kurtosis:                      22.669   Cond. No.                         5.70
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                Ret_SMB   R-squared:                       0.480
# Model:                            OLS   Adj. R-squared:                  0.475
# Method:                 Least Squares   F-statistic:                     109.1
# Date:                Sun, 01 Oct 2023   Prob (F-statistic):           2.66e-97
# Time:                        16:31:02   Log-Likelihood:                -2393.4
# No. Observations:                 717   AIC:                             4801.
# Df Residuals:                     710   BIC:                             4833.
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.3772      0.272     -1.389      0.165      -0.910       0.156
# Mkt-RF         0.0784      0.065      1.212      0.226      -0.049       0.205
# SMB            2.2970      0.096     24.002      0.000       2.109       2.485
# HML            0.1671      0.123      1.358      0.175      -0.074       0.409
# RMW            0.6944      0.129      5.368      0.000       0.440       0.948
# CMA            0.0548      0.184      0.298      0.766      -0.306       0.415
# MOM           -0.0194      0.064     -0.304      0.761      -0.145       0.106
# ==============================================================================
# Omnibus:                      247.511   Durbin-Watson:                   1.482
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            17357.743
# Skew:                          -0.625   Prob(JB):                         0.00
# Kurtosis:                      27.072   Cond. No.                         5.38
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        rolling_var_HML   R-squared:                       0.539
# Model:                            OLS   Adj. R-squared:                  0.539
# Method:                 Least Squares   F-statistic:                     1355.
# Date:                Sun, 01 Oct 2023   Prob (F-statistic):          4.74e-197
# Time:                        16:31:02   Log-Likelihood:                -868.51
# No. Observations:                1160   AIC:                             1741.
# Df Residuals:                    1158   BIC:                             1751.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.1004      0.017      5.976      0.000       0.067       0.133
# lag_vol        0.7346      0.020     36.811      0.000       0.695       0.774
# ==============================================================================
# Omnibus:                     1064.125   Durbin-Watson:                   2.387
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            68938.719
# Skew:                           3.979   Prob(JB):                         0.00
# Kurtosis:                      39.919   Cond. No.                         1.67
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    HML   R-squared:                       0.008
# Model:                            OLS   Adj. R-squared:                  0.007
# Method:                 Least Squares   F-statistic:                     9.359
# Date:                Sun, 01 Oct 2023   Prob (F-statistic):            0.00227
# Time:                        16:31:02   Log-Likelihood:                -3117.5
# No. Observations:                1160   AIC:                             6239.
# Df Residuals:                    1158   BIC:                             6249.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.1911      0.117      1.638      0.102      -0.038       0.420
# lag_vol        0.4243      0.139      3.059      0.002       0.152       0.696
# ==============================================================================
# Omnibus:                      573.391   Durbin-Watson:                   1.577
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            13617.183
# Skew:                           1.750   Prob(JB):                         0.00
# Kurtosis:                      19.416   Cond. No.                         1.67
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                Ret_HML   R-squared:                       0.309
# Model:                            OLS   Adj. R-squared:                  0.308
# Method:                 Least Squares   F-statistic:                     517.9
# Date:                Sun, 01 Oct 2023   Prob (F-statistic):           4.68e-95
# Time:                        16:31:02   Log-Likelihood:                -4134.6
# No. Observations:                1160   AIC:                             8273.
# Df Residuals:                    1158   BIC:                             8283.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.4140      0.252      1.641      0.101      -0.081       0.909
# HML            1.6007      0.070     22.758      0.000       1.463       1.739
# ==============================================================================
# Omnibus:                      253.798   Durbin-Watson:                   1.624
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             9144.647
# Skew:                          -0.056   Prob(JB):                         0.00
# Kurtosis:                      16.755   Cond. No.                         3.61
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                Ret_HML   R-squared:                       0.331
# Model:                            OLS   Adj. R-squared:                  0.329
# Method:                 Least Squares   F-statistic:                     190.5
# Date:                Sun, 01 Oct 2023   Prob (F-statistic):          2.27e-100
# Time:                        16:31:02   Log-Likelihood:                -4116.0
# No. Observations:                1160   AIC:                             8240.
# Df Residuals:                    1156   BIC:                             8260.
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.5757      0.250      2.303      0.021       0.085       1.066
# Mkt-RF        -0.2849      0.050     -5.727      0.000      -0.383      -0.187
# SMB           -0.0321      0.082     -0.391      0.696      -0.194       0.129
# HML            1.7016      0.071     23.885      0.000       1.562       1.841
# ==============================================================================
# Omnibus:                      251.260   Durbin-Watson:                   1.649
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             8804.362
# Skew:                           0.046   Prob(JB):                         0.00
# Kurtosis:                      16.496   Cond. No.                         5.70
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                Ret_HML   R-squared:                       0.442
# Model:                            OLS   Adj. R-squared:                  0.437
# Method:                 Least Squares   F-statistic:                     93.78
# Date:                Sun, 01 Oct 2023   Prob (F-statistic):           1.32e-86
# Time:                        16:31:02   Log-Likelihood:                -2529.3
# No. Observations:                 717   AIC:                             5073.
# Df Residuals:                     710   BIC:                             5105.
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.8662      0.328      2.639      0.009       0.222       1.511
# Mkt-RF        -0.1221      0.078     -1.562      0.119      -0.276       0.031
# SMB           -0.1977      0.116     -1.709      0.088      -0.425       0.029
# HML            2.4962      0.149     16.782      0.000       2.204       2.788
# RMW           -1.2660      0.156     -8.097      0.000      -1.573      -0.959
# CMA           -0.3352      0.222     -1.510      0.132      -0.771       0.101
# MOM            0.1043      0.077      1.349      0.178      -0.047       0.256
# ==============================================================================
# Omnibus:                      184.548   Durbin-Watson:                   1.657
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             6873.101
# Skew:                           0.355   Prob(JB):                         0.00
# Kurtosis:                      18.151   Cond. No.                         5.38
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        rolling_var_RMW   R-squared:                       0.523
# Model:                            OLS   Adj. R-squared:                  0.522
# Method:                 Least Squares   F-statistic:                     782.5
# Date:                Sun, 01 Oct 2023   Prob (F-statistic):          7.73e-117
# Time:                        16:31:02   Log-Likelihood:                 104.16
# No. Observations:                 716   AIC:                            -204.3
# Df Residuals:                     714   BIC:                            -195.2
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0432      0.009      4.912      0.000       0.026       0.060
# lag_vol        0.7231      0.026     27.972      0.000       0.672       0.774
# ==============================================================================
# Omnibus:                      721.121   Durbin-Watson:                   2.191
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           120965.471
# Skew:                           4.091   Prob(JB):                         0.00
# Kurtosis:                      66.149   Cond. No.                         3.39
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    RMW   R-squared:                       0.019
# Model:                            OLS   Adj. R-squared:                  0.017
# Method:                 Least Squares   F-statistic:                     13.66
# Date:                Sun, 01 Oct 2023   Prob (F-statistic):           0.000235
# Time:                        16:31:02   Log-Likelihood:                -1580.9
# No. Observations:                 716   AIC:                             3166.
# Df Residuals:                     714   BIC:                             3175.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.1248      0.092      1.349      0.178      -0.057       0.306
# lag_vol        1.0053      0.272      3.697      0.000       0.471       1.539
# ==============================================================================
# Omnibus:                      212.377   Durbin-Watson:                   1.731
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             4347.068
# Skew:                          -0.799   Prob(JB):                         0.00
# Kurtosis:                      14.965   Cond. No.                         3.39
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                Ret_RMW   R-squared:                       0.332
# Model:                            OLS   Adj. R-squared:                  0.331
# Method:                 Least Squares   F-statistic:                     354.7
# Date:                Sun, 01 Oct 2023   Prob (F-statistic):           1.54e-64
# Time:                        16:31:02   Log-Likelihood:                -2048.2
# No. Observations:                 716   AIC:                             4100.
# Df Residuals:                     714   BIC:                             4109.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.4759      0.159      2.984      0.003       0.163       0.789
# RMW            1.3409      0.071     18.833      0.000       1.201       1.481
# ==============================================================================
# Omnibus:                      223.933   Durbin-Watson:                   1.817
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2315.269
# Skew:                           1.091   Prob(JB):                         0.00
# Kurtosis:                      11.535   Cond. No.                         2.27
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                Ret_RMW   R-squared:                       0.096
# Model:                            OLS   Adj. R-squared:                  0.092
# Method:                 Least Squares   F-statistic:                     25.17
# Date:                Sun, 01 Oct 2023   Prob (F-statistic):           1.73e-15
# Time:                        16:31:02   Log-Likelihood:                -2156.4
# No. Observations:                 716   AIC:                             4321.
# Df Residuals:                     712   BIC:                             4339.
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          1.0499      0.187      5.605      0.000       0.682       1.418
# Mkt-RF        -0.0029      0.044     -0.066      0.947      -0.088       0.083
# SMB           -0.4123      0.064     -6.475      0.000      -0.537      -0.287
# HML           -0.4095      0.063     -6.453      0.000      -0.534      -0.285
# ==============================================================================
# Omnibus:                      154.173   Durbin-Watson:                   1.772
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              931.946
# Skew:                           0.815   Prob(JB):                    4.27e-203
# Kurtosis:                       8.346   Cond. No.                         4.84
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                Ret_RMW   R-squared:                       0.397
# Model:                            OLS   Adj. R-squared:                  0.392
# Method:                 Least Squares   F-statistic:                     77.79
# Date:                Sun, 01 Oct 2023   Prob (F-statistic):           1.36e-74
# Time:                        16:31:02   Log-Likelihood:                -2011.5
# No. Observations:                 716   AIC:                             4037.
# Df Residuals:                     709   BIC:                             4069.
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.6110      0.160      3.814      0.000       0.296       0.925
# Mkt-RF         0.0222      0.038      0.583      0.560      -0.053       0.097
# SMB           -0.0242      0.056     -0.430      0.668      -0.135       0.086
# HML           -0.3378      0.073     -4.658      0.000      -0.480      -0.195
# RMW            1.3728      0.076     18.008      0.000       1.223       1.522
# CMA           -0.1859      0.108     -1.716      0.087      -0.399       0.027
# MOM            0.0014      0.038      0.038      0.970      -0.073       0.075
# ==============================================================================
# Omnibus:                      232.902   Durbin-Watson:                   1.841
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1914.645
# Skew:                           1.221   Prob(JB):                         0.00
# Kurtosis:                      10.630   Cond. No.                         5.39
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        rolling_var_CMA   R-squared:                       0.472
# Model:                            OLS   Adj. R-squared:                  0.471
# Method:                 Least Squares   F-statistic:                     637.8
# Date:                Sun, 01 Oct 2023   Prob (F-statistic):          4.75e-101
# Time:                        16:31:02   Log-Likelihood:                 302.00
# No. Observations:                 716   AIC:                            -600.0
# Df Residuals:                     714   BIC:                            -590.9
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0441      0.007      6.252      0.000       0.030       0.058
# lag_vol        0.6871      0.027     25.254      0.000       0.634       0.741
# ==============================================================================
# Omnibus:                      511.792   Durbin-Watson:                   2.347
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            27237.941
# Skew:                           2.590   Prob(JB):                         0.00
# Kurtosis:                      32.769   Cond. No.                         4.67
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    CMA   R-squared:                       0.023
# Model:                            OLS   Adj. R-squared:                  0.022
# Method:                 Least Squares   F-statistic:                     16.72
# Date:                Sun, 01 Oct 2023   Prob (F-statistic):           4.81e-05
# Time:                        16:31:02   Log-Likelihood:                -1525.8
# No. Observations:                 716   AIC:                             3056.
# Df Residuals:                     714   BIC:                             3065.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0906      0.091      1.001      0.317      -0.087       0.268
# lag_vol        1.4290      0.349      4.090      0.000       0.743       2.115
# ==============================================================================
# Omnibus:                       20.072   Durbin-Watson:                   1.758
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               43.118
# Skew:                          -0.052   Prob(JB):                     4.34e-10
# Kurtosis:                       4.198   Cond. No.                         4.67
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                Ret_CMA   R-squared:                       0.472
# Model:                            OLS   Adj. R-squared:                  0.472
# Method:                 Least Squares   F-statistic:                     639.0
# Date:                Sun, 01 Oct 2023   Prob (F-statistic):          3.45e-101
# Time:                        16:31:02   Log-Likelihood:                -1794.6
# No. Observations:                 716   AIC:                             3593.
# Df Residuals:                     714   BIC:                             3602.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0637      0.112      0.568      0.570      -0.156       0.284
# CMA            1.3612      0.054     25.278      0.000       1.255       1.467
# ==============================================================================
# Omnibus:                      146.954   Durbin-Watson:                   1.860
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              896.820
# Skew:                           0.765   Prob(JB):                    1.81e-195
# Kurtosis:                       8.265   Cond. No.                         2.11
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                Ret_CMA   R-squared:                       0.245
# Model:                            OLS   Adj. R-squared:                  0.242
# Method:                 Least Squares   F-statistic:                     77.03
# Date:                Sun, 01 Oct 2023   Prob (F-statistic):           3.71e-43
# Time:                        16:31:02   Log-Likelihood:                -1922.8
# No. Observations:                 716   AIC:                             3854.
# Df Residuals:                     712   BIC:                             3872.
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.3061      0.135      2.264      0.024       0.041       0.571
# Mkt-RF        -0.0822      0.031     -2.617      0.009      -0.144      -0.021
# SMB            0.0464      0.046      1.009      0.313      -0.044       0.137
# HML            0.6475      0.046     14.140      0.000       0.558       0.737
# ==============================================================================
# Omnibus:                       92.188   Durbin-Watson:                   1.902
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              404.991
# Skew:                           0.500   Prob(JB):                     1.14e-88
# Kurtosis:                       6.546   Cond. No.                         4.84
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                Ret_CMA   R-squared:                       0.514
# Model:                            OLS   Adj. R-squared:                  0.510
# Method:                 Least Squares   F-statistic:                     124.8
# Date:                Sun, 01 Oct 2023   Prob (F-statistic):          1.77e-107
# Time:                        16:31:02   Log-Likelihood:                -1765.4
# No. Observations:                 716   AIC:                             3545.
# Df Residuals:                     709   BIC:                             3577.
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.1817      0.114      1.600      0.110      -0.041       0.405
# Mkt-RF         0.0353      0.027      1.307      0.192      -0.018       0.088
# SMB           -0.0506      0.040     -1.265      0.206      -0.129       0.028
# HML            0.0597      0.051      1.160      0.246      -0.041       0.161
# RMW           -0.3517      0.054     -6.506      0.000      -0.458      -0.246
# CMA            1.3101      0.077     17.058      0.000       1.159       1.461
# MOM           -0.0531      0.027     -1.986      0.047      -0.105      -0.001
# ==============================================================================
# Omnibus:                      161.869   Durbin-Watson:                   1.867
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              879.380
# Skew:                           0.898   Prob(JB):                    1.11e-191
# Kurtosis:                       8.123   Cond. No.                         5.39
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        rolling_var_MOM   R-squared:                       0.405
# Model:                            OLS   Adj. R-squared:                  0.404
# Method:                 Least Squares   F-statistic:                     783.2
# Date:                Sun, 01 Oct 2023   Prob (F-statistic):          6.06e-132
# Time:                        16:31:02   Log-Likelihood:                -1509.2
# No. Observations:                1155   AIC:                             3022.
# Df Residuals:                    1153   BIC:                             3032.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.2097      0.029      7.136      0.000       0.152       0.267
# lag_vol        0.6360      0.023     27.986      0.000       0.591       0.681
# ==============================================================================
# Omnibus:                     1229.512   Durbin-Watson:                   2.296
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           173224.386
# Skew:                           4.805   Prob(JB):                         0.00
# Kurtosis:                      62.221   Cond. No.                         1.73
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    MOM   R-squared:                       0.023
# Model:                            OLS   Adj. R-squared:                  0.022
# Method:                 Least Squares   F-statistic:                     27.27
# Date:                Sun, 01 Oct 2023   Prob (F-statistic):           2.09e-07
# Time:                        16:31:02   Log-Likelihood:                -3415.3
# No. Observations:                1155   AIC:                             6835.
# Df Residuals:                    1153   BIC:                             6845.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.9855      0.153      6.439      0.000       0.685       1.286
# lag_vol       -0.6182      0.118     -5.222      0.000      -0.850      -0.386
# ==============================================================================
# Omnibus:                      775.951   Durbin-Watson:                   1.934
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            29361.747
# Skew:                          -2.561   Prob(JB):                         0.00
# Kurtosis:                      27.163   Cond. No.                         1.73
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                Ret_MOM   R-squared:                       0.227
# Model:                            OLS   Adj. R-squared:                  0.226
# Method:                 Least Squares   F-statistic:                     338.2
# Date:                Sun, 01 Oct 2023   Prob (F-statistic):           1.96e-66
# Time:                        16:31:02   Log-Likelihood:                -4590.9
# No. Observations:                1155   AIC:                             9186.
# Df Residuals:                    1153   BIC:                             9196.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          3.0741      0.383      8.031      0.000       2.323       3.825
# MOM            1.4812      0.081     18.390      0.000       1.323       1.639
# ==============================================================================
# Omnibus:                      406.297   Durbin-Watson:                   1.676
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             9808.304
# Skew:                           1.057   Prob(JB):                         0.00
# Kurtosis:                      17.119   Cond. No.                         4.80
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                Ret_MOM   R-squared:                       0.023
# Model:                            OLS   Adj. R-squared:                  0.020
# Method:                 Least Squares   F-statistic:                     8.895
# Date:                Sun, 01 Oct 2023   Prob (F-statistic):           7.89e-06
# Time:                        16:31:02   Log-Likelihood:                -4726.2
# No. Observations:                1155   AIC:                             9460.
# Df Residuals:                    1151   BIC:                             9481.
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          4.1979      0.431      9.732      0.000       3.352       5.044
# Mkt-RF         0.0966      0.086      1.126      0.260      -0.072       0.265
# SMB           -0.3855      0.142     -2.720      0.007      -0.664      -0.107
# HML           -0.5162      0.123     -4.205      0.000      -0.757      -0.275
# ==============================================================================
# Omnibus:                      276.213   Durbin-Watson:                   1.718
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             4983.285
# Skew:                           0.608   Prob(JB):                         0.00
# Kurtosis:                      13.103   Cond. No.                         5.71
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                Ret_MOM   R-squared:                       0.312
# Model:                            OLS   Adj. R-squared:                  0.306
# Method:                 Least Squares   F-statistic:                     53.55
# Date:                Sun, 01 Oct 2023   Prob (F-statistic):           1.75e-54
# Time:                        16:31:02   Log-Likelihood:                -2796.4
# No. Observations:                 717   AIC:                             5607.
# Df Residuals:                     710   BIC:                             5639.
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          2.9851      0.476      6.266      0.000       2.050       3.920
# Mkt-RF         0.3556      0.113      3.135      0.002       0.133       0.578
# SMB           -0.2976      0.168     -1.773      0.077      -0.627       0.032
# HML            0.4442      0.216      2.058      0.040       0.020       0.868
# RMW           -0.0948      0.227     -0.418      0.676      -0.540       0.351
# CMA           -0.7174      0.322     -2.226      0.026      -1.350      -0.085
# MOM            1.9596      0.112     17.478      0.000       1.740       2.180
# ==============================================================================
# Omnibus:                      362.848   Durbin-Watson:                   1.646
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             4552.590
# Skew:                           1.959   Prob(JB):                         0.00
# Kurtosis:                      14.706   Cond. No.                         5.38
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ### Q2 (a) - Aggregate Portfolio

# %%
factordaily_res = pd.read_csv('ff6_daily_factors.csv', usecols = [0])

for factor in factorlist:
    factordaily = ffdaily[['date', factor]].copy()
    # Calculate rolling variance
    factordaily['rolling_var_'+factor] = factordaily[factor].rolling(window=22, min_periods=22).var()
    factordaily['inverse_var_'+factor] = 1/ factordaily['rolling_var_'+factor]
    
    # Collapse to Monthly
    factordaily['mdate'] = (factordaily['date']/100).astype(int)
    factordaily = factordaily.drop_duplicates('mdate', keep='last')
    
    factordaily = factordaily[['mdate', 'inverse_var_'+factor, 'rolling_var_'+factor]].copy()
    factordaily = factordaily.rename(columns={'mdate':'date'})
    factordaily_res = pd.merge(factordaily_res, factordaily, on='date', how='right')

factormonthly = pd.merge(ffmonthly, factordaily_res, on='date', how='left')

factormonthly['sum_inv_var'] = factormonthly[['inverse_var_'+ factor for factor in factorlist]].sum(axis=1)

for factor in factorlist:
    factormonthly['weight_'+factor] = factormonthly['inverse_var_'+ factor]/factormonthly['sum_inv_var']
    factormonthly['Ret_'+factor] = factormonthly['weight_'+factor].shift(1)*(factormonthly[factor])

factormonthly['portfolio_return'] = factormonthly[['Ret_'+ factor for factor in factorlist]].sum(axis=1)
factormonthly
# Out:
#         date  Mkt-RF   SMB   HML    RF    MOM   RMW   CMA  inverse_var_Mkt-RF  \
# 0     192607    2.96 -2.56 -2.43  0.22    NaN   NaN   NaN            4.376654
# 1     192608    2.64 -1.17  3.82  0.25    NaN   NaN   NaN            2.678081
# 2     192609    0.36 -1.40  0.13  0.23    NaN   NaN   NaN            3.925430
# 3     192610   -3.24 -0.09  0.70  0.32    NaN   NaN   NaN            1.445235
# 4     192611    2.53 -0.10 -0.51  0.31    NaN   NaN   NaN            6.535384
# ...      ...     ...   ...   ...   ...    ...   ...   ...                 ...
# 1156  202211    4.60 -3.40  1.38  0.29  -2.01  6.01  3.11            0.314242
# 1157  202212   -6.41 -0.68  1.32  0.33   4.52  0.09  4.19            0.545313
# 1158  202301    6.65  5.02 -4.05  0.35 -15.98 -2.62 -4.53            0.855394
# 1159  202302   -2.58  1.21 -0.78  0.34   0.20  0.90 -1.41            0.895622
# 1160  202303    2.51 -5.59 -9.01  0.36  -2.52  1.92 -2.29            0.683783
#
#       rolling_var_Mkt-RF  ...   Ret_SMB  weight_HML   Ret_HML  weight_RMW  \
# 0               0.228485  ...       NaN    0.323044       NaN         NaN
# 1               0.373402  ... -0.520281    0.488781  1.234027         NaN
# 2               0.254749  ... -0.532345    0.458706  0.063541         NaN
# 3               0.691929  ... -0.039779    0.368577  0.321094         NaN
# 4               0.153013  ... -0.051449    0.267933 -0.187974         NaN
# ...                  ...  ...       ...         ...       ...         ...
# 1156            3.182266  ... -1.033056    0.125249  0.227922    0.249365
# 1157            1.833809  ... -0.254384    0.109277  0.165329    0.240928
# 1158            1.169051  ...  1.713529    0.162961 -0.442570    0.248558
# 1159            1.116542  ...  0.339789    0.114553 -0.127110    0.385534
# 1160            1.462451  ... -1.084016    0.071910 -1.032121    0.303530
#
#        Ret_RMW  weight_CMA   Ret_CMA  weight_MOM   Ret_MOM  portfolio_return
# 0          NaN         NaN       NaN         NaN       NaN          0.000000
# 1          NaN         NaN       NaN         NaN       NaN          1.326944
# 2          NaN         NaN       NaN         NaN       NaN         -0.421653
# 3          NaN         NaN       NaN         NaN       NaN         -0.040440
# 4          NaN         NaN       NaN    0.114200       NaN          0.056407
# ...        ...         ...       ...         ...       ...               ...
# 1156  1.130954    0.172719  0.732165    0.030258 -0.144437          1.077022
# 1157  0.022443    0.206769  0.723694    0.052359  0.136765          0.484153
# 1158 -0.631232    0.195053 -0.936665    0.049611 -0.836689         -0.805606
# 1159  0.223702    0.176478 -0.275024    0.037724  0.009922          0.008739
# 1160  0.740226    0.241669 -0.404136    0.116866 -0.095064         -1.644718
#
# [1161 rows x 34 columns]

# %% [markdown]
# ### Q2 (b) - Alphas using CAPM, FF3 and FF5+MOM models on the Aggregate Portfolio

# %%
# Asset pricing test of the CAPM
cols = ['portfolio_return', 'Mkt-RF']
returndf = factormonthly[cols].copy().dropna()
model1=sm.OLS(returndf['portfolio_return'],sm.add_constant(returndf['Mkt-RF'])).fit()
print(model1.summary())

# AP Test FF3
cols = ['portfolio_return', 'Mkt-RF','SMB', 'HML']
returndf = factormonthly[cols].copy().dropna()
model2=sm.OLS(returndf['portfolio_return'],sm.add_constant(returndf[['Mkt-RF','SMB', 'HML']])).fit()
print(model2.summary())

# AP Test FF5 + MOM
cols = ['portfolio_return', 'Mkt-RF','SMB', 'HML', 'RMW', 'CMA', 'MOM']
returndf = factormonthly[cols].copy().dropna()
model3=sm.OLS(returndf['portfolio_return'], sm.add_constant(returndf[['Mkt-RF','SMB', 'HML', 'RMW', 'CMA', 'MOM']])).fit()
print(model3.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:       portfolio_return   R-squared:                       0.084
# Model:                            OLS   Adj. R-squared:                  0.083
# Method:                 Least Squares   F-statistic:                     105.9
# Date:                Sun, 01 Oct 2023   Prob (F-statistic):           7.88e-24
# Time:                        16:31:16   Log-Likelihood:                -2067.0
# No. Observations:                1161   AIC:                             4138.
# Df Residuals:                    1159   BIC:                             4148.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.3049      0.042      7.175      0.000       0.222       0.388
# Mkt-RF         0.0811      0.008     10.291      0.000       0.066       0.097
# ==============================================================================
# Omnibus:                      604.343   Durbin-Watson:                   1.826
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            17569.591
# Skew:                           1.819   Prob(JB):                         0.00
# Kurtosis:                      21.707   Cond. No.                         5.44
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:       portfolio_return   R-squared:                       0.489
# Model:                            OLS   Adj. R-squared:                  0.487
# Method:                 Least Squares   F-statistic:                     368.5
# Date:                Sun, 01 Oct 2023   Prob (F-statistic):          6.27e-168
# Time:                        16:31:16   Log-Likelihood:                -1728.5
# No. Observations:                1161   AIC:                             3465.
# Df Residuals:                    1157   BIC:                             3485.
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.2393      0.032      7.510      0.000       0.177       0.302
# Mkt-RF         0.0147      0.006      2.315      0.021       0.002       0.027
# SMB            0.1751      0.010     16.700      0.000       0.155       0.196
# HML            0.2218      0.009     24.419      0.000       0.204       0.240
# ==============================================================================
# Omnibus:                      220.525   Durbin-Watson:                   1.883
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             3565.782
# Skew:                          -0.369   Prob(JB):                         0.00
# Kurtosis:                      11.554   Cond. No.                         5.70
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:       portfolio_return   R-squared:                       0.668
# Model:                            OLS   Adj. R-squared:                  0.665
# Method:                 Least Squares   F-statistic:                     238.0
# Date:                Sun, 01 Oct 2023   Prob (F-statistic):          3.09e-166
# Time:                        16:31:16   Log-Likelihood:                -621.36
# No. Observations:                 717   AIC:                             1257.
# Df Residuals:                     710   BIC:                             1289.
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0793      0.023      3.459      0.001       0.034       0.124
# Mkt-RF         0.0449      0.005      8.218      0.000       0.034       0.056
# SMB            0.1210      0.008     14.967      0.000       0.105       0.137
# HML            0.1156      0.010     11.126      0.000       0.095       0.136
# RMW            0.1968      0.011     18.012      0.000       0.175       0.218
# CMA            0.2269      0.016     14.623      0.000       0.196       0.257
# MOM            0.0709      0.005     13.131      0.000       0.060       0.081
# ==============================================================================
# Omnibus:                      120.496   Durbin-Watson:                   1.697
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              689.458
# Skew:                          -0.609   Prob(JB):                    1.93e-150
# Kurtosis:                       7.647   Cond. No.                         5.38
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
