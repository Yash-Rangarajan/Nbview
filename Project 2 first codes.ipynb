# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.api as sm
from scipy.optimize import minimize
from numpy.linalg import inv,norm
from scipy.special import beta,betainc
from sklearn.linear_model import LassoLars, lars_path

# %%
# Defining a file path and loading excel file
xls_file = pd.ExcelFile('Data_Project_2.xlsx')
e_worksheet_name = xls_file.sheet_names

# %%
# Extract all worksheets from excel and assign to new variable dataframes
famafrench = xls_file.parse(e_worksheet_name[0])
mutualfund = xls_file.parse(e_worksheet_name[1])
smartbeta = xls_file.parse(e_worksheet_name[2])
hedgefund = xls_file.parse(e_worksheet_name[3])

# %%
famafrench = famafrench[(famafrench['Date']>=200101) & (famafrench['Date']<=201912)]

# %%
# Reset index after selecting data based on dates for all worksheets.
# This is done so that we can run regression based on same Df length.

famafrench = famafrench.reset_index(drop=True)
famafrench
# Out:
#        Date  mktrf   smb    hml   RMW   CMA    rf    umd
# 0    200101   3.13  5.78  -5.28 -5.31 -6.55  0.54 -25.05
# 1    200102 -10.05  2.63  12.60  9.09  9.56  0.38  12.51
# 2    200103  -7.26  2.27   6.52  3.27  3.94  0.42   8.35
# 3    200104   7.94 -0.67  -4.74 -3.42 -3.95  0.39  -7.97
# 4    200105   0.72  3.55   3.38  0.17  2.18  0.32   2.12
# ..      ...    ...   ...    ...   ...   ...   ...    ...
# 223  201908  -2.58 -3.30  -4.93  0.43 -0.88  0.16   7.66
# 224  201909   1.43  0.26   6.78  1.99  3.50  0.18  -6.85
# 225  201910   2.06  0.21  -2.09  0.25 -0.99  0.15   0.29
# 226  201911   3.87  0.50  -1.87 -1.58 -1.24  0.12  -2.60
# 227  201912   2.77  0.96   1.93  0.09  1.29  0.14  -2.27
#
# [228 rows x 8 columns]

# %%
mutualfund = mutualfund.iloc[12:]
# Assuming the end date of each worksheet is the same end date as 
# Famafrench worksheet, we will copy the columns 'Date' into the other 
# worksheets. As mentioned in the previous cell, we will reset the index
# before copying columns.
mutualfund = mutualfund.reset_index(drop=True)
mutualfund['Date'] = famafrench['Date']
mutualfund_excess = pd.DataFrame()
for i in mutualfund.iloc[:,1:]:
    mutualfund_excess[i] = (mutualfund[i]-(famafrench['rf']/100))
mutualfund_excess['Date'] = mutualfund['Date']
mutualfund_excess
# Out:
#         FSMEX     FSELX     INPIX     SLMCX     CSEIX     FSPHX     NASDX  \
# 0   -0.027630  0.408666  0.108570  0.238078  0.041540 -0.008050  0.098904
# 1    0.016364 -0.297978 -0.508751 -0.205961 -0.014710 -0.017997 -0.267668
# 2   -0.090673 -0.075910 -0.397533 -0.073921  0.004991 -0.088075 -0.183426
# 3    0.012327  0.253523  0.334561  0.235072  0.042474  0.025668  0.174760
# 4    0.065974 -0.074223 -0.024136 -0.025668  0.016253  0.025640 -0.032674
# ..        ...       ...       ...       ...       ...       ...       ...
# 223 -0.013437 -0.038220 -0.095215 -0.030842  0.047591 -0.028800 -0.022455
# 224 -0.016282  0.043034 -0.033417  0.019207  0.002948 -0.026060  0.004057
# 225  0.019545  0.062866 -0.014216  0.044437  0.021359  0.065504  0.043998
# 226  0.061344  0.055768  0.041037  0.051132 -0.037205  0.088847 -0.027088
# 227  0.004955  0.036743  0.011292 -0.060417  0.022866  0.034832  0.108844
#
#         JAENX     JENSX     DAPAX    Date
# 0    0.045285 -0.036892  0.131434  200101
# 1   -0.221774 -0.025203 -0.136422  200102
# 2   -0.184689 -0.061902 -0.090705  200103
# 3    0.142741  0.035611  0.083330  200104
# 4   -0.014627  0.021063 -0.020552  200105
# ..        ...       ...       ...     ...
# 223 -0.018193 -0.012694 -0.012344  201908
# 224  0.008382  0.010205 -0.004127  201909
# 225 -0.003588  0.015058  0.024939  201910
# 226  0.038408  0.034090  0.045012  201911
# 227 -0.024231 -0.042341 -0.023124  201912
#
# [228 rows x 11 columns]

# %%
smartbeta = smartbeta.reset_index(drop=True)
smartbeta['Date'] = famafrench['Date']
smartbeta_excess = pd.DataFrame()
for i in smartbeta.iloc[:,1:]:
    smartbeta_excess[i] = (smartbeta[i]-(famafrench['rf']/100))
smartbeta_excess['Date'] = smartbeta['Date']

# %%
hedgefund = hedgefund[(hedgefund['Date']>=200101) & (hedgefund['Date']<=201912)]
hedgefund.reset_index(drop=True,inplace=True)
hedgefund['Date'] = famafrench['Date']
hedgefund_excess = pd.DataFrame()
for i in hedgefund.iloc[:,1:]:
    hedgefund_excess[i] = (hedgefund[i]-(famafrench['rf']/100))
hedgefund_excess['Date'] = hedgefund['Date']

# %%
# Define a function to test for alpha under FF5+MOM
def FF5MOM_test(df1):
    LIST=[]
    
    # Use a for loop to parse through all the columns of each df
    for column in df1.iloc[:,1:]:
        returndf1 = df1[column].copy()
        
        # to account for nan values, we fill them with the mean of the column
        returndf1.fillna(returndf1.mean(),inplace=True)
        model_famafrench = sm.OLS(returndf1, sm.add_constant(famafrench.iloc[:,[1,2,3,4,5,7]])).fit()
        model = model_famafrench.summary()
        LIST.append(model)
    return LIST

# %%
FF5MOM_test(mutualfund_excess)
# Out:
# [<class 'statsmodels.iolib.summary.Summary'>
#  """
#                              OLS Regression Results
#  ==============================================================================
#  Dep. Variable:                  FSELX   R-squared:                       0.731
#  Model:                            OLS   Adj. R-squared:                  0.723
#  Method:                 Least Squares   F-statistic:                     99.87
#  Date:                Sun, 22 Oct 2023   Prob (F-statistic):           3.93e-60
#  Time:                        00:41:37   Log-Likelihood:                 367.17
#  No. Observations:                 228   AIC:                            -720.3
#  Df Residuals:                     221   BIC:                            -696.3
#  Df Model:                           6
#  Covariance Type:            nonrobust
#  ==============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
#  ------------------------------------------------------------------------------
#  const          0.0045      0.003      1.319      0.189      -0.002       0.011
#  mktrf          0.0129      0.001     13.207      0.000       0.011       0.015
#  smb            0.0050      0.001      3.579      0.000       0.002       0.008
#  hml           -0.0062      0.002     -3.953      0.000      -0.009      -0.003
#  RMW           -0.0065      0.002     -3.391      0.001      -0.010      -0.003
#  CMA           -0.0030      0.002     -1.340      0.182      -0.007       0.001
#  umd           -0.0027      0.001     -3.479      0.001      -0.004      -0.001
#  ==============================================================================
#  Omnibus:                       10.736   Durbin-Watson:                   2.271
#  Prob(Omnibus):                  0.005   Jarque-Bera (JB):               12.418
#  Skew:                           0.402   Prob(JB):                      0.00201
#  Kurtosis:                       3.813   Cond. No.                         6.43
#  ==============================================================================
#
#  Notes:
#  [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#  """,
#  <class 'statsmodels.iolib.summary.Summary'>
#  """
#                              OLS Regression Results
#  ==============================================================================
#  Dep. Variable:                  INPIX   R-squared:                       0.826
#  Model:                            OLS   Adj. R-squared:                  0.821
#  Method:                 Least Squares   F-statistic:                     174.9
#  Date:                Sun, 22 Oct 2023   Prob (F-statistic):           5.12e-81
#  Time:                        00:41:37   Log-Likelihood:                 350.97
#  No. Observations:                 228   AIC:                            -687.9
#  Df Residuals:                     221   BIC:                            -663.9
#  Df Model:                           6
#  Covariance Type:            nonrobust
#  ==============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
#  ------------------------------------------------------------------------------
#  const          0.0083      0.004      2.241      0.026       0.001       0.016
#  mktrf          0.0179      0.001     17.052      0.000       0.016       0.020
#  smb            0.0013      0.001      0.875      0.382      -0.002       0.004
#  hml           -0.0102      0.002     -6.060      0.000      -0.014      -0.007
#  RMW           -0.0162      0.002     -7.869      0.000      -0.020      -0.012
#  CMA           -0.0058      0.002     -2.407      0.017      -0.010      -0.001
#  umd           -0.0014      0.001     -1.710      0.089      -0.003       0.000
#  ==============================================================================
#  Omnibus:                       10.068   Durbin-Watson:                   1.922
#  Prob(Omnibus):                  0.007   Jarque-Bera (JB):               16.860
#  Skew:                           0.219   Prob(JB):                     0.000218
#  Kurtosis:                       4.258   Cond. No.                         6.43
#  ==============================================================================
#
#  Notes:
#  [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#  """,
#  <class 'statsmodels.iolib.summary.Summary'>
#  """
#                              OLS Regression Results
#  ==============================================================================
#  Dep. Variable:                  SLMCX   R-squared:                       0.730
#  Model:                            OLS   Adj. R-squared:                  0.723
#  Method:                 Least Squares   F-statistic:                     99.56
#  Date:                Sun, 22 Oct 2023   Prob (F-statistic):           5.05e-60
#  Time:                        00:41:37   Log-Likelihood:                 434.00
#  No. Observations:                 228   AIC:                            -854.0
#  Df Residuals:                     221   BIC:                            -830.0
#  Df Model:                           6
#  Covariance Type:            nonrobust
#  ==============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
#  ------------------------------------------------------------------------------
#  const          0.0048      0.003      1.878      0.062      -0.000       0.010
#  mktrf          0.0105      0.001     14.380      0.000       0.009       0.012
#  smb            0.0028      0.001      2.693      0.008       0.001       0.005
#  hml           -0.0046      0.001     -3.942      0.000      -0.007      -0.002
#  RMW           -0.0032      0.001     -2.247      0.026      -0.006      -0.000
#  CMA           -0.0051      0.002     -3.058      0.003      -0.008      -0.002
#  umd           -0.0013      0.001     -2.181      0.030      -0.002      -0.000
#  ==============================================================================
#  Omnibus:                       26.496   Durbin-Watson:                   2.405
#  Prob(Omnibus):                  0.000   Jarque-Bera (JB):               89.109
#  Skew:                           0.382   Prob(JB):                     4.47e-20
#  Kurtosis:                       5.966   Cond. No.                         6.43
#  ==============================================================================
#
#  Notes:
#  [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#  """,
#  <class 'statsmodels.iolib.summary.Summary'>
#  """
#                              OLS Regression Results
#  ==============================================================================
#  Dep. Variable:                  CSEIX   R-squared:                       0.348
#  Model:                            OLS   Adj. R-squared:                  0.331
#  Method:                 Least Squares   F-statistic:                     19.68
#  Date:                Sun, 22 Oct 2023   Prob (F-statistic):           2.26e-18
#  Time:                        00:41:37   Log-Likelihood:                 334.16
#  No. Observations:                 228   AIC:                            -654.3
#  Df Residuals:                     221   BIC:                            -630.3
#  Df Model:                           6
#  Covariance Type:            nonrobust
#  ==============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
#  ------------------------------------------------------------------------------
#  const          0.0026      0.004      0.646      0.519      -0.005       0.010
#  mktrf          0.0085      0.001      7.532      0.000       0.006       0.011
#  smb            0.0032      0.002      1.981      0.049    1.58e-05       0.006
#  hml            0.0033      0.002      1.814      0.071      -0.000       0.007
#  RMW            0.0042      0.002      1.897      0.059      -0.000       0.009
#  CMA            0.0002      0.003      0.084      0.933      -0.005       0.005
#  umd           -0.0014      0.001     -1.592      0.113      -0.003       0.000
#  ==============================================================================
#  Omnibus:                       57.352   Durbin-Watson:                   2.609
#  Prob(Omnibus):                  0.000   Jarque-Bera (JB):              350.636
#  Skew:                           0.793   Prob(JB):                     7.25e-77
#  Kurtosis:                       8.864   Cond. No.                         6.43
#  ==============================================================================
#
#  Notes:
#  [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#  """,
#  <class 'statsmodels.iolib.summary.Summary'>
#  """
#                              OLS Regression Results
#  ==============================================================================
#  Dep. Variable:                  FSPHX   R-squared:                       0.017
#  Model:                            OLS   Adj. R-squared:                 -0.009
#  Method:                 Least Squares   F-statistic:                    0.6537
#  Date:                Sun, 22 Oct 2023   Prob (F-statistic):              0.687
#  Time:                        00:41:37   Log-Likelihood:                -274.22
#  No. Observations:                 228   AIC:                             562.4
#  Df Residuals:                     221   BIC:                             586.4
#  Df Model:                           6
#  Covariance Type:            nonrobust
#  ==============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
#  ------------------------------------------------------------------------------
#  const          0.0896      0.057      1.563      0.120      -0.023       0.203
#  mktrf         -0.0127      0.016     -0.784      0.434      -0.045       0.019
#  smb            0.0030      0.023      0.128      0.898      -0.043       0.049
#  hml            0.0453      0.026      1.731      0.085      -0.006       0.097
#  RMW           -0.0099      0.032     -0.308      0.758      -0.073       0.053
#  CMA           -0.0353      0.037     -0.950      0.343      -0.109       0.038
#  umd           -0.0058      0.013     -0.455      0.649      -0.031       0.019
#  ==============================================================================
#  Omnibus:                      413.790   Durbin-Watson:                   2.221
#  Prob(Omnibus):                  0.000   Jarque-Bera (JB):           103190.976
#  Skew:                          10.004   Prob(JB):                         0.00
#  Kurtosis:                     105.283   Cond. No.                         6.43
#  ==============================================================================
#
#  Notes:
#  [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#  """,
#  <class 'statsmodels.iolib.summary.Summary'>
#  """
#                              OLS Regression Results
#  ==============================================================================
#  Dep. Variable:                  NASDX   R-squared:                       0.884
#  Model:                            OLS   Adj. R-squared:                  0.881
#  Method:                 Least Squares   F-statistic:                     281.9
#  Date:                Sun, 22 Oct 2023   Prob (F-statistic):          1.37e-100
#  Time:                        00:41:37   Log-Likelihood:                 551.44
#  No. Observations:                 228   AIC:                            -1089.
#  Df Residuals:                     221   BIC:                            -1065.
#  Df Model:                           6
#  Covariance Type:            nonrobust
#  ==============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
#  ------------------------------------------------------------------------------
#  const          0.0029      0.002      1.863      0.064      -0.000       0.006
#  mktrf          0.0113      0.000     25.946      0.000       0.010       0.012
#  smb           -0.0004      0.001     -0.591      0.555      -0.002       0.001
#  hml           -0.0055      0.001     -7.849      0.000      -0.007      -0.004
#  RMW           -0.0042      0.001     -4.920      0.000      -0.006      -0.003
#  CMA           -0.0025      0.001     -2.470      0.014      -0.004      -0.000
#  umd           -0.0010      0.000     -3.034      0.003      -0.002      -0.000
#  ==============================================================================
#  Omnibus:                       16.457   Durbin-Watson:                   2.263
#  Prob(Omnibus):                  0.000   Jarque-Bera (JB):               50.450
#  Skew:                           0.067   Prob(JB):                     1.11e-11
#  Kurtosis:                       5.301   Cond. No.                         6.43
#  ==============================================================================
#
#  Notes:
#  [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#  """,
#  <class 'statsmodels.iolib.summary.Summary'>
#  """
#                              OLS Regression Results
#  ==============================================================================
#  Dep. Variable:                  JAENX   R-squared:                       0.850
#  Model:                            OLS   Adj. R-squared:                  0.846
#  Method:                 Least Squares   F-statistic:                     209.0
#  Date:                Sun, 22 Oct 2023   Prob (F-statistic):           3.68e-88
#  Time:                        00:41:37   Log-Likelihood:                 558.84
#  No. Observations:                 228   AIC:                            -1104.
#  Df Residuals:                     221   BIC:                            -1080.
#  Df Model:                           6
#  Covariance Type:            nonrobust
#  ==============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
#  ------------------------------------------------------------------------------
#  const          0.0003      0.001      0.233      0.816      -0.003       0.003
#  mktrf          0.0102      0.000     24.200      0.000       0.009       0.011
#  smb            0.0025      0.001      4.221      0.000       0.001       0.004
#  hml           -0.0023      0.001     -3.463      0.001      -0.004      -0.001
#  RMW           -0.0005      0.001     -0.625      0.533      -0.002       0.001
#  CMA           -0.0040      0.001     -4.130      0.000      -0.006      -0.002
#  umd           -0.0004      0.000     -1.113      0.267      -0.001       0.000
#  ==============================================================================
#  Omnibus:                       18.152   Durbin-Watson:                   2.192
#  Prob(Omnibus):                  0.000   Jarque-Bera (JB):               62.169
#  Skew:                           0.017   Prob(JB):                     3.16e-14
#  Kurtosis:                       5.558   Cond. No.                         6.43
#  ==============================================================================
#
#  Notes:
#  [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#  """,
#  <class 'statsmodels.iolib.summary.Summary'>
#  """
#                              OLS Regression Results
#  ==============================================================================
#  Dep. Variable:                  JENSX   R-squared:                       0.756
#  Model:                            OLS   Adj. R-squared:                  0.749
#  Method:                 Least Squares   F-statistic:                     114.1
#  Date:                Sun, 22 Oct 2023   Prob (F-statistic):           7.22e-65
#  Time:                        00:41:37   Log-Likelihood:                 566.33
#  No. Observations:                 228   AIC:                            -1119.
#  Df Residuals:                     221   BIC:                            -1095.
#  Df Model:                           6
#  Covariance Type:            nonrobust
#  ==============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
#  ------------------------------------------------------------------------------
#  const         -0.0006      0.001     -0.385      0.701      -0.003       0.002
#  mktrf          0.0093      0.000     22.778      0.000       0.008       0.010
#  smb           -0.0012      0.001     -2.061      0.040      -0.002   -5.25e-05
#  hml           -0.0004      0.001     -0.623      0.534      -0.002       0.001
#  RMW            0.0029      0.001      3.584      0.000       0.001       0.004
#  CMA            0.0019      0.001      2.072      0.039    9.38e-05       0.004
#  umd           -0.0001      0.000     -0.376      0.708      -0.001       0.001
#  ==============================================================================
#  Omnibus:                       71.397   Durbin-Watson:                   2.569
#  Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1076.176
#  Skew:                           0.726   Prob(JB):                    2.05e-234
#  Kurtosis:                      13.544   Cond. No.                         6.43
#  ==============================================================================
#
#  Notes:
#  [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#  """,
#  <class 'statsmodels.iolib.summary.Summary'>
#  """
#                              OLS Regression Results
#  ==============================================================================
#  Dep. Variable:                  DAPAX   R-squared:                       0.718
#  Model:                            OLS   Adj. R-squared:                  0.710
#  Method:                 Least Squares   F-statistic:                     93.78
#  Date:                Sun, 22 Oct 2023   Prob (F-statistic):           5.85e-58
#  Time:                        00:41:37   Log-Likelihood:                 492.56
#  No. Observations:                 228   AIC:                            -971.1
#  Df Residuals:                     221   BIC:                            -947.1
#  Df Model:                           6
#  Covariance Type:            nonrobust
#  ==============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
#  ------------------------------------------------------------------------------
#  const         -0.0007      0.002     -0.346      0.730      -0.005       0.003
#  mktrf          0.0100      0.001     17.839      0.000       0.009       0.011
#  smb           -0.0002      0.001     -0.228      0.820      -0.002       0.001
#  hml           -0.0027      0.001     -2.928      0.004      -0.004      -0.001
#  RMW            0.0002      0.001      0.217      0.829      -0.002       0.002
#  CMA           -0.0024      0.001     -1.883      0.061      -0.005       0.000
#  umd           -0.0002      0.000     -0.369      0.712      -0.001       0.001
#  ==============================================================================
#  Omnibus:                       81.566   Durbin-Watson:                   2.701
#  Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1926.170
#  Skew:                           0.755   Prob(JB):                         0.00
#  Kurtosis:                      17.159   Cond. No.                         6.43
#  ==============================================================================
#
#  Notes:
#  [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#  """,
#  <class 'statsmodels.iolib.summary.Summary'>
#  """
#                              OLS Regression Results
#  ==============================================================================
#  Dep. Variable:                   Date   R-squared:                       0.083
#  Model:                            OLS   Adj. R-squared:                  0.058
#  Method:                 Least Squares   F-statistic:                     3.327
#  Date:                Sun, 22 Oct 2023   Prob (F-statistic):            0.00371
#  Time:                        00:41:37   Log-Likelihood:                -1751.4
#  No. Observations:                 228   AIC:                             3517.
#  Df Residuals:                     221   BIC:                             3541.
#  Df Model:                           6
#  Covariance Type:            nonrobust
#  ==============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
#  ------------------------------------------------------------------------------
#  const        2.01e+05     37.325   5385.549      0.000    2.01e+05    2.01e+05
#  mktrf         21.4376     10.582      2.026      0.044       0.582      42.293
#  smb          -46.8676     15.155     -3.093      0.002     -76.734     -17.001
#  hml           -9.8204     17.054     -0.576      0.565     -43.431      23.790
#  RMW          -21.3551     20.808     -1.026      0.306     -62.363      19.653
#  CMA          -20.3181     24.202     -0.840      0.402     -68.015      27.379
#  umd            8.4759      8.348      1.015      0.311      -7.977      24.929
#  ==============================================================================
#  Omnibus:                       33.752   Durbin-Watson:                   0.174
#  Prob(Omnibus):                  0.000   Jarque-Bera (JB):                8.820
#  Skew:                           0.001   Prob(JB):                       0.0122
#  Kurtosis:                       2.036   Cond. No.                         6.43
#  ==============================================================================
#
#  Notes:
#  [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#  """]

# %%
FF5MOM_test(smartbeta_excess)
# Out:
# [<class 'statsmodels.iolib.summary.Summary'>
#  """
#                              OLS Regression Results
#  ==============================================================================
#  Dep. Variable:                   DWAQ   R-squared:                       0.732
#  Model:                            OLS   Adj. R-squared:                  0.725
#  Method:                 Least Squares   F-statistic:                     100.6
#  Date:                Sun, 22 Oct 2023   Prob (F-statistic):           2.17e-60
#  Time:                        00:41:37   Log-Likelihood:                 518.99
#  No. Observations:                 228   AIC:                            -1024.
#  Df Residuals:                     221   BIC:                            -1000.
#  Df Model:                           6
#  Covariance Type:            nonrobust
#  ==============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
#  ------------------------------------------------------------------------------
#  const       8.548e-05      0.002      0.048      0.961      -0.003       0.004
#  mktrf          0.0095      0.001     19.009      0.000       0.009       0.011
#  smb            0.0055      0.001      7.639      0.000       0.004       0.007
#  hml           -0.0002      0.001     -0.308      0.758      -0.002       0.001
#  RMW            0.0013      0.001      1.284      0.200      -0.001       0.003
#  CMA           -0.0007      0.001     -0.577      0.565      -0.003       0.002
#  umd            0.0032      0.000      8.149      0.000       0.002       0.004
#  ==============================================================================
#  Omnibus:                       16.610   Durbin-Watson:                   1.731
#  Prob(Omnibus):                  0.000   Jarque-Bera (JB):               31.903
#  Skew:                           0.364   Prob(JB):                     1.18e-07
#  Kurtosis:                       4.682   Cond. No.                         6.43
#  ==============================================================================
#
#  Notes:
#  [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#  """,
#  <class 'statsmodels.iolib.summary.Summary'>
#  """
#                              OLS Regression Results
#  ==============================================================================
#  Dep. Variable:                    FPX   R-squared:                       0.678
#  Model:                            OLS   Adj. R-squared:                  0.669
#  Method:                 Least Squares   F-statistic:                     77.62
#  Date:                Sun, 22 Oct 2023   Prob (F-statistic):           1.14e-51
#  Time:                        00:41:37   Log-Likelihood:                 523.51
#  No. Observations:                 228   AIC:                            -1033.
#  Df Residuals:                     221   BIC:                            -1009.
#  Df Model:                           6
#  Covariance Type:            nonrobust
#  ==============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
#  ------------------------------------------------------------------------------
#  const          0.0022      0.002      1.289      0.199      -0.001       0.006
#  mktrf          0.0092      0.000     18.718      0.000       0.008       0.010
#  smb            0.0023      0.001      3.310      0.001       0.001       0.004
#  hml           -0.0001      0.001     -0.161      0.872      -0.002       0.001
#  RMW            0.0047      0.001      4.906      0.000       0.003       0.007
#  CMA           -0.0017      0.001     -1.545      0.124      -0.004       0.000
#  umd            0.0012      0.000      2.982      0.003       0.000       0.002
#  ==============================================================================
#  Omnibus:                        6.646   Durbin-Watson:                   1.680
#  Prob(Omnibus):                  0.036   Jarque-Bera (JB):                9.993
#  Skew:                           0.117   Prob(JB):                      0.00676
#  Kurtosis:                       3.999   Cond. No.                         6.43
#  ==============================================================================
#
#  Notes:
#  [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#  """,
#  <class 'statsmodels.iolib.summary.Summary'>
#  """
#                              OLS Regression Results
#  ==============================================================================
#  Dep. Variable:                    PWC   R-squared:                       0.804
#  Model:                            OLS   Adj. R-squared:                  0.799
#  Method:                 Least Squares   F-statistic:                     151.3
#  Date:                Sun, 22 Oct 2023   Prob (F-statistic):           2.24e-75
#  Time:                        00:41:37   Log-Likelihood:                 601.31
#  No. Observations:                 228   AIC:                            -1189.
#  Df Residuals:                     221   BIC:                            -1165.
#  Df Model:                           6
#  Covariance Type:            nonrobust
#  ==============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
#  ------------------------------------------------------------------------------
#  const         -0.0003      0.001     -0.248      0.804      -0.003       0.002
#  mktrf          0.0089      0.000     25.618      0.000       0.008       0.010
#  smb            0.0029      0.001      5.809      0.000       0.002       0.004
#  hml            0.0012      0.001      2.061      0.040    5.11e-05       0.002
#  RMW            0.0034      0.001      4.939      0.000       0.002       0.005
#  CMA           -0.0003      0.001     -0.367      0.714      -0.002       0.001
#  umd            0.0019      0.000      7.012      0.000       0.001       0.002
#  ==============================================================================
#  Omnibus:                       38.833   Durbin-Watson:                   1.716
#  Prob(Omnibus):                  0.000   Jarque-Bera (JB):              117.002
#  Skew:                           0.692   Prob(JB):                     3.92e-26
#  Kurtosis:                       6.225   Cond. No.                         6.43
#  ==============================================================================
#
#  Notes:
#  [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#  """,
#  <class 'statsmodels.iolib.summary.Summary'>
#  """
#                              OLS Regression Results
#  ==============================================================================
#  Dep. Variable:                    DLN   R-squared:                       0.768
#  Model:                            OLS   Adj. R-squared:                  0.761
#  Method:                 Least Squares   F-statistic:                     121.8
#  Date:                Sun, 22 Oct 2023   Prob (F-statistic):           3.23e-67
#  Time:                        00:41:37   Log-Likelihood:                 617.02
#  No. Observations:                 228   AIC:                            -1220.
#  Df Residuals:                     221   BIC:                            -1196.
#  Df Model:                           6
#  Covariance Type:            nonrobust
#  ==============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
#  ------------------------------------------------------------------------------
#  const          0.0011      0.001      0.947      0.345      -0.001       0.003
#  mktrf          0.0075      0.000     22.876      0.000       0.007       0.008
#  smb           -0.0007      0.000     -1.596      0.112      -0.002       0.000
#  hml            0.0027      0.001      5.171      0.000       0.002       0.004
#  RMW            0.0042      0.001      6.613      0.000       0.003       0.006
#  CMA         9.538e-05      0.001      0.128      0.898      -0.001       0.002
#  umd           -0.0001      0.000     -0.546      0.586      -0.001       0.000
#  ==============================================================================
#  Omnibus:                       19.952   Durbin-Watson:                   1.858
#  Prob(Omnibus):                  0.000   Jarque-Bera (JB):               74.459
#  Skew:                           0.058   Prob(JB):                     6.78e-17
#  Kurtosis:                       5.797   Cond. No.                         6.43
#  ==============================================================================
#
#  Notes:
#  [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#  """,
#  <class 'statsmodels.iolib.summary.Summary'>
#  """
#                              OLS Regression Results
#  ==============================================================================
#  Dep. Variable:                    PSL   R-squared:                       0.528
#  Model:                            OLS   Adj. R-squared:                  0.516
#  Method:                 Least Squares   F-statistic:                     41.27
#  Date:                Sun, 22 Oct 2023   Prob (F-statistic):           1.52e-33
#  Time:                        00:41:37   Log-Likelihood:                 567.62
#  No. Observations:                 228   AIC:                            -1121.
#  Df Residuals:                     221   BIC:                            -1097.
#  Df Model:                           6
#  Covariance Type:            nonrobust
#  ==============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
#  ------------------------------------------------------------------------------
#  const          0.0031      0.001      2.186      0.030       0.000       0.006
#  mktrf          0.0057      0.000     14.165      0.000       0.005       0.007
#  smb            0.0009      0.001      1.578      0.116      -0.000       0.002
#  hml            0.0003      0.001      0.518      0.605      -0.001       0.002
#  RMW            0.0032      0.001      4.042      0.000       0.002       0.005
#  CMA           -0.0002      0.001     -0.253      0.800      -0.002       0.002
#  umd            0.0007      0.000      2.329      0.021       0.000       0.001
#  ==============================================================================
#  Omnibus:                        9.577   Durbin-Watson:                   2.009
#  Prob(Omnibus):                  0.008   Jarque-Bera (JB):               15.521
#  Skew:                          -0.216   Prob(JB):                     0.000426
#  Kurtosis:                       4.203   Cond. No.                         6.43
#  ==============================================================================
#
#  Notes:
#  [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#  """,
#  <class 'statsmodels.iolib.summary.Summary'>
#  """
#                              OLS Regression Results
#  ==============================================================================
#  Dep. Variable:                    RSP   R-squared:                       0.817
#  Model:                            OLS   Adj. R-squared:                  0.812
#  Method:                 Least Squares   F-statistic:                     164.7
#  Date:                Sun, 22 Oct 2023   Prob (F-statistic):           1.16e-78
#  Time:                        00:41:37   Log-Likelihood:                 588.92
#  No. Observations:                 228   AIC:                            -1164.
#  Df Residuals:                     221   BIC:                            -1140.
#  Df Model:                           6
#  Covariance Type:            nonrobust
#  ==============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
#  ------------------------------------------------------------------------------
#  const          0.0011      0.001      0.817      0.415      -0.002       0.004
#  mktrf          0.0093      0.000     25.159      0.000       0.009       0.010
#  smb            0.0025      0.001      4.817      0.000       0.002       0.004
#  hml            0.0016      0.001      2.691      0.008       0.000       0.003
#  RMW            0.0044      0.001      6.050      0.000       0.003       0.006
#  CMA            0.0014      0.001      1.635      0.103      -0.000       0.003
#  umd           -0.0002      0.000     -0.547      0.585      -0.001       0.000
#  ==============================================================================
#  Omnibus:                       77.611   Durbin-Watson:                   1.733
#  Prob(Omnibus):                  0.000   Jarque-Bera (JB):              440.320
#  Skew:                           1.198   Prob(JB):                     2.43e-96
#  Kurtosis:                       9.372   Cond. No.                         6.43
#  ==============================================================================
#
#  Notes:
#  [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#  """,
#  <class 'statsmodels.iolib.summary.Summary'>
#  """
#                              OLS Regression Results
#  ==============================================================================
#  Dep. Variable:                    NFO   R-squared:                       0.701
#  Model:                            OLS   Adj. R-squared:                  0.693
#  Method:                 Least Squares   F-statistic:                     86.51
#  Date:                Sun, 22 Oct 2023   Prob (F-statistic):           3.12e-55
#  Time:                        00:41:38   Log-Likelihood:                 524.18
#  No. Observations:                 228   AIC:                            -1034.
#  Df Residuals:                     221   BIC:                            -1010.
#  Df Model:                           6
#  Covariance Type:            nonrobust
#  ==============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
#  ------------------------------------------------------------------------------
#  const          0.0008      0.002      0.441      0.660      -0.003       0.004
#  mktrf          0.0088      0.000     17.947      0.000       0.008       0.010
#  smb            0.0030      0.001      4.247      0.000       0.002       0.004
#  hml            0.0017      0.001      2.143      0.033       0.000       0.003
#  RMW            0.0057      0.001      5.920      0.000       0.004       0.008
#  CMA           -0.0010      0.001     -0.905      0.366      -0.003       0.001
#  umd           -0.0005      0.000     -1.228      0.221      -0.001       0.000
#  ==============================================================================
#  Omnibus:                       44.686   Durbin-Watson:                   1.840
#  Prob(Omnibus):                  0.000   Jarque-Bera (JB):              123.740
#  Skew:                           0.838   Prob(JB):                     1.35e-27
#  Kurtosis:                       6.196   Cond. No.                         6.43
#  ==============================================================================
#
#  Notes:
#  [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#  """,
#  <class 'statsmodels.iolib.summary.Summary'>
#  """
#                              OLS Regression Results
#  ==============================================================================
#  Dep. Variable:                   SPHQ   R-squared:                       0.697
#  Model:                            OLS   Adj. R-squared:                  0.689
#  Method:                 Least Squares   F-statistic:                     84.77
#  Date:                Sun, 22 Oct 2023   Prob (F-statistic):           1.48e-54
#  Time:                        00:41:38   Log-Likelihood:                 563.49
#  No. Observations:                 228   AIC:                            -1113.
#  Df Residuals:                     221   BIC:                            -1089.
#  Df Model:                           6
#  Covariance Type:            nonrobust
#  ==============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
#  ------------------------------------------------------------------------------
#  const         -0.0007      0.001     -0.455      0.649      -0.004       0.002
#  mktrf          0.0085      0.000     20.572      0.000       0.008       0.009
#  smb            0.0017      0.001      2.847      0.005       0.001       0.003
#  hml        -2.995e-05      0.001     -0.045      0.964      -0.001       0.001
#  RMW            0.0046      0.001      5.639      0.000       0.003       0.006
#  CMA           -0.0007      0.001     -0.745      0.457      -0.003       0.001
#  umd            0.0019      0.000      5.919      0.000       0.001       0.003
#  ==============================================================================
#  Omnibus:                       36.208   Durbin-Watson:                   1.714
#  Prob(Omnibus):                  0.000   Jarque-Bera (JB):              113.400
#  Skew:                          -0.625   Prob(JB):                     2.37e-25
#  Kurtosis:                       6.221   Cond. No.                         6.43
#  ==============================================================================
#
#  Notes:
#  [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#  """,
#  <class 'statsmodels.iolib.summary.Summary'>
#  """
#                              OLS Regression Results
#  ==============================================================================
#  Dep. Variable:                    CVY   R-squared:                       0.676
#  Model:                            OLS   Adj. R-squared:                  0.667
#  Method:                 Least Squares   F-statistic:                     76.76
#  Date:                Sun, 22 Oct 2023   Prob (F-statistic):           2.58e-51
#  Time:                        00:41:38   Log-Likelihood:                 524.55
#  No. Observations:                 228   AIC:                            -1035.
#  Df Residuals:                     221   BIC:                            -1011.
#  Df Model:                           6
#  Covariance Type:            nonrobust
#  ==============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
#  ------------------------------------------------------------------------------
#  const         -0.0022      0.002     -1.254      0.211      -0.006       0.001
#  mktrf          0.0076      0.000     15.561      0.000       0.007       0.009
#  smb            0.0006      0.001      0.851      0.396      -0.001       0.002
#  hml            0.0028      0.001      3.605      0.000       0.001       0.004
#  RMW            0.0065      0.001      6.796      0.000       0.005       0.008
#  CMA           -0.0004      0.001     -0.355      0.723      -0.003       0.002
#  umd           -0.0022      0.000     -5.596      0.000      -0.003      -0.001
#  ==============================================================================
#  Omnibus:                        9.152   Durbin-Watson:                   1.893
#  Prob(Omnibus):                  0.010   Jarque-Bera (JB):               13.635
#  Skew:                           0.240   Prob(JB):                      0.00109
#  Kurtosis:                       4.098   Cond. No.                         6.43
#  ==============================================================================
#
#  Notes:
#  [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#  """,
#  <class 'statsmodels.iolib.summary.Summary'>
#  """
#                              OLS Regression Results
#  ==============================================================================
#  Dep. Variable:                   Date   R-squared:                       0.083
#  Model:                            OLS   Adj. R-squared:                  0.058
#  Method:                 Least Squares   F-statistic:                     3.327
#  Date:                Sun, 22 Oct 2023   Prob (F-statistic):            0.00371
#  Time:                        00:41:38   Log-Likelihood:                -1751.4
#  No. Observations:                 228   AIC:                             3517.
#  Df Residuals:                     221   BIC:                             3541.
#  Df Model:                           6
#  Covariance Type:            nonrobust
#  ==============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
#  ------------------------------------------------------------------------------
#  const        2.01e+05     37.325   5385.549      0.000    2.01e+05    2.01e+05
#  mktrf         21.4376     10.582      2.026      0.044       0.582      42.293
#  smb          -46.8676     15.155     -3.093      0.002     -76.734     -17.001
#  hml           -9.8204     17.054     -0.576      0.565     -43.431      23.790
#  RMW          -21.3551     20.808     -1.026      0.306     -62.363      19.653
#  CMA          -20.3181     24.202     -0.840      0.402     -68.015      27.379
#  umd            8.4759      8.348      1.015      0.311      -7.977      24.929
#  ==============================================================================
#  Omnibus:                       33.752   Durbin-Watson:                   0.174
#  Prob(Omnibus):                  0.000   Jarque-Bera (JB):                8.820
#  Skew:                           0.001   Prob(JB):                       0.0122
#  Kurtosis:                       2.036   Cond. No.                         6.43
#  ==============================================================================
#
#  Notes:
#  [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#  """]

# %%
FF5MOM_test(hedgefund_excess)
# Out:
# [<class 'statsmodels.iolib.summary.Summary'>
#  """
#                              OLS Regression Results
#  ==============================================================================
#  Dep. Variable:                HFRIMAI   R-squared:                       0.461
#  Model:                            OLS   Adj. R-squared:                  0.447
#  Method:                 Least Squares   F-statistic:                     31.56
#  Date:                Sun, 22 Oct 2023   Prob (F-statistic):           2.73e-27
#  Time:                        00:41:38   Log-Likelihood:                 834.93
#  No. Observations:                 228   AIC:                            -1656.
#  Df Residuals:                     221   BIC:                            -1632.
#  Df Model:                           6
#  Covariance Type:            nonrobust
#  ==============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
#  ------------------------------------------------------------------------------
#  const          0.0015      0.000      3.472      0.001       0.001       0.002
#  mktrf          0.0013      0.000     10.343      0.000       0.001       0.002
#  smb            0.0005      0.000      2.863      0.005       0.000       0.001
#  hml           -0.0001      0.000     -0.659      0.510      -0.001       0.000
#  RMW        -2.711e-05      0.000     -0.110      0.913      -0.001       0.000
#  CMA         1.171e-05      0.000      0.041      0.967      -0.001       0.001
#  umd            0.0002   9.89e-05      1.638      0.103    -3.3e-05       0.000
#  ==============================================================================
#  Omnibus:                        8.039   Durbin-Watson:                   1.824
#  Prob(Omnibus):                  0.018   Jarque-Bera (JB):                8.742
#  Skew:                          -0.338   Prob(JB):                       0.0126
#  Kurtosis:                       3.681   Cond. No.                         6.43
#  ==============================================================================
#
#  Notes:
#  [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#  """,
#  <class 'statsmodels.iolib.summary.Summary'>
#  """
#                              OLS Regression Results
#  ==============================================================================
#  Dep. Variable:               HFRIEMNI   R-squared:                       0.381
#  Model:                            OLS   Adj. R-squared:                  0.364
#  Method:                 Least Squares   F-statistic:                     22.63
#  Date:                Sun, 22 Oct 2023   Prob (F-statistic):           9.71e-21
#  Time:                        00:41:38   Log-Likelihood:                 855.38
#  No. Observations:                 228   AIC:                            -1697.
#  Df Residuals:                     221   BIC:                            -1673.
#  Df Model:                           6
#  Covariance Type:            nonrobust
#  ==============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
#  ------------------------------------------------------------------------------
#  const          0.0003      0.000      0.735      0.463      -0.000       0.001
#  mktrf          0.0010      0.000      9.083      0.000       0.001       0.001
#  smb            0.0002      0.000      1.011      0.313      -0.000       0.000
#  hml            0.0003      0.000      1.426      0.155      -0.000       0.001
#  RMW            0.0003      0.000      1.494      0.137      -0.000       0.001
#  CMA            0.0002      0.000      0.882      0.379      -0.000       0.001
#  umd            0.0007   9.04e-05      8.283      0.000       0.001       0.001
#  ==============================================================================
#  Omnibus:                       47.600   Durbin-Watson:                   1.856
#  Prob(Omnibus):                  0.000   Jarque-Bera (JB):              132.221
#  Skew:                          -0.894   Prob(JB):                     1.94e-29
#  Kurtosis:                       6.275   Cond. No.                         6.43
#  ==============================================================================
#
#  Notes:
#  [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#  """,
#  <class 'statsmodels.iolib.summary.Summary'>
#  """
#                              OLS Regression Results
#  ==============================================================================
#  Dep. Variable:               HFRIENHI   R-squared:                       0.809
#  Model:                            OLS   Adj. R-squared:                  0.804
#  Method:                 Least Squares   F-statistic:                     156.1
#  Date:                Sun, 22 Oct 2023   Prob (F-statistic):           1.38e-76
#  Time:                        00:41:38   Log-Likelihood:                 687.47
#  No. Observations:                 228   AIC:                            -1361.
#  Df Residuals:                     221   BIC:                            -1337.
#  Df Model:                           6
#  Covariance Type:            nonrobust
#  ==============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
#  ------------------------------------------------------------------------------
#  const          0.0011      0.001      1.280      0.202      -0.001       0.003
#  mktrf          0.0049      0.000     20.617      0.000       0.004       0.005
#  smb            0.0017      0.000      4.887      0.000       0.001       0.002
#  hml           -0.0012      0.000     -3.012      0.003      -0.002      -0.000
#  RMW           -0.0014      0.000     -2.876      0.004      -0.002      -0.000
#  CMA           -0.0004      0.001     -0.686      0.494      -0.001       0.001
#  umd            0.0001      0.000      0.692      0.489      -0.000       0.001
#  ==============================================================================
#  Omnibus:                        0.466   Durbin-Watson:                   1.722
#  Prob(Omnibus):                  0.792   Jarque-Bera (JB):                0.300
#  Skew:                           0.082   Prob(JB):                        0.860
#  Kurtosis:                       3.070   Cond. No.                         6.43
#  ==============================================================================
#
#  Notes:
#  [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#  """,
#  <class 'statsmodels.iolib.summary.Summary'>
#  """
#                              OLS Regression Results
#  ==============================================================================
#  Dep. Variable:                 HFRIEM   R-squared:                       0.531
#  Model:                            OLS   Adj. R-squared:                  0.518
#  Method:                 Least Squares   F-statistic:                     41.63
#  Date:                Sun, 22 Oct 2023   Prob (F-statistic):           9.14e-34
#  Time:                        00:41:38   Log-Likelihood:                 557.79
#  No. Observations:                 228   AIC:                            -1102.
#  Df Residuals:                     221   BIC:                            -1078.
#  Df Model:                           6
#  Covariance Type:            nonrobust
#  ==============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
#  ------------------------------------------------------------------------------
#  const          0.0025      0.001      1.708      0.089      -0.000       0.005
#  mktrf          0.0049      0.000     11.570      0.000       0.004       0.006
#  smb            0.0009      0.001      1.561      0.120      -0.000       0.002
#  hml            0.0003      0.001      0.414      0.679      -0.001       0.002
#  RMW            0.0007      0.001      0.807      0.420      -0.001       0.002
#  CMA           -0.0013      0.001     -1.333      0.184      -0.003       0.001
#  umd           -0.0003      0.000     -0.993      0.322      -0.001       0.000
#  ==============================================================================
#  Omnibus:                        3.889   Durbin-Watson:                   1.484
#  Prob(Omnibus):                  0.143   Jarque-Bera (JB):                3.651
#  Skew:                          -0.223   Prob(JB):                        0.161
#  Kurtosis:                       3.430   Cond. No.                         6.43
#  ==============================================================================
#
#  Notes:
#  [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#  """,
#  <class 'statsmodels.iolib.summary.Summary'>
#  """
#                              OLS Regression Results
#  ==============================================================================
#  Dep. Variable:                HFRIEHI   R-squared:                       0.788
#  Model:                            OLS   Adj. R-squared:                  0.783
#  Method:                 Least Squares   F-statistic:                     137.3
#  Date:                Sun, 22 Oct 2023   Prob (F-statistic):           1.13e-71
#  Time:                        00:41:38   Log-Likelihood:                 721.36
#  No. Observations:                 228   AIC:                            -1429.
#  Df Residuals:                     221   BIC:                            -1405.
#  Df Model:                           6
#  Covariance Type:            nonrobust
#  ==============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
#  ------------------------------------------------------------------------------
#  const          0.0002      0.001      0.262      0.794      -0.001       0.002
#  mktrf          0.0044      0.000     21.297      0.000       0.004       0.005
#  smb            0.0014      0.000      4.897      0.000       0.001       0.002
#  hml           -0.0002      0.000     -0.463      0.644      -0.001       0.001
#  RMW         7.877e-05      0.000      0.194      0.846      -0.001       0.001
#  CMA           -0.0007      0.000     -1.448      0.149      -0.002       0.000
#  umd            0.0003      0.000      1.589      0.114   -6.22e-05       0.001
#  ==============================================================================
#  Omnibus:                       20.816   Durbin-Watson:                   1.618
#  Prob(Omnibus):                  0.000   Jarque-Bera (JB):               73.948
#  Skew:                          -0.174   Prob(JB):                     8.76e-17
#  Kurtosis:                       5.768   Cond. No.                         6.43
#  ==============================================================================
#
#  Notes:
#  [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#  """,
#  <class 'statsmodels.iolib.summary.Summary'>
#  """
#                              OLS Regression Results
#  ==============================================================================
#  Dep. Variable:                HFRIEDI   R-squared:                       0.669
#  Model:                            OLS   Adj. R-squared:                  0.660
#  Method:                 Least Squares   F-statistic:                     74.52
#  Date:                Sun, 22 Oct 2023   Prob (F-statistic):           2.29e-50
#  Time:                        00:41:38   Log-Likelihood:                 727.21
#  No. Observations:                 228   AIC:                            -1440.
#  Df Residuals:                     221   BIC:                            -1416.
#  Df Model:                           6
#  Covariance Type:            nonrobust
#  ==============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
#  ------------------------------------------------------------------------------
#  const          0.0023      0.001      3.262      0.001       0.001       0.004
#  mktrf          0.0028      0.000     14.059      0.000       0.002       0.003
#  smb            0.0013      0.000      4.499      0.000       0.001       0.002
#  hml            0.0003      0.000      0.806      0.421      -0.000       0.001
#  RMW           -0.0004      0.000     -1.111      0.268      -0.001       0.000
#  CMA         3.315e-05      0.000      0.072      0.943      -0.001       0.001
#  umd        -4.081e-05      0.000     -0.257      0.797      -0.000       0.000
#  ==============================================================================
#  Omnibus:                       16.745   Durbin-Watson:                   1.464
#  Prob(Omnibus):                  0.000   Jarque-Bera (JB):               28.829
#  Skew:                          -0.411   Prob(JB):                     5.49e-07
#  Kurtosis:                       4.536   Cond. No.                         6.43
#  ==============================================================================
#
#  Notes:
#  [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#  """,
#  <class 'statsmodels.iolib.summary.Summary'>
#  """
#                              OLS Regression Results
#  ==============================================================================
#  Dep. Variable:                 HFRIMI   R-squared:                       0.089
#  Model:                            OLS   Adj. R-squared:                  0.064
#  Method:                 Least Squares   F-statistic:                     3.582
#  Date:                Sun, 22 Oct 2023   Prob (F-statistic):            0.00208
#  Time:                        00:41:38   Log-Likelihood:                 663.58
#  No. Observations:                 228   AIC:                            -1313.
#  Df Residuals:                     221   BIC:                            -1289.
#  Df Model:                           6
#  Covariance Type:            nonrobust
#  ==============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
#  ------------------------------------------------------------------------------
#  const          0.0020      0.001      2.104      0.036       0.000       0.004
#  mktrf          0.0010      0.000      3.625      0.000       0.000       0.001
#  smb            0.0002      0.000      0.585      0.559      -0.001       0.001
#  hml           -0.0007      0.000     -1.667      0.097      -0.002       0.000
#  RMW            0.0001      0.001      0.202      0.840      -0.001       0.001
#  CMA         8.317e-05      0.001      0.137      0.891      -0.001       0.001
#  umd            0.0004      0.000      2.118      0.035    3.08e-05       0.001
#  ==============================================================================
#  Omnibus:                       10.442   Durbin-Watson:                   2.045
#  Prob(Omnibus):                  0.005   Jarque-Bera (JB):               12.476
#  Skew:                           0.378   Prob(JB):                      0.00195
#  Kurtosis:                       3.862   Cond. No.                         6.43
#  ==============================================================================
#
#  Notes:
#  [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#  """,
#  <class 'statsmodels.iolib.summary.Summary'>
#  """
#                              OLS Regression Results
#  ==============================================================================
#  Dep. Variable:                HFRIMTI   R-squared:                       0.138
#  Model:                            OLS   Adj. R-squared:                  0.115
#  Method:                 Least Squares   F-statistic:                     5.905
#  Date:                Sun, 22 Oct 2023   Prob (F-statistic):           9.79e-06
#  Time:                        00:41:38   Log-Likelihood:                 566.26
#  No. Observations:                 228   AIC:                            -1119.
#  Df Residuals:                     221   BIC:                            -1095.
#  Df Model:                           6
#  Covariance Type:            nonrobust
#  ==============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
#  ------------------------------------------------------------------------------
#  const          0.0021      0.001      1.456      0.147      -0.001       0.005
#  mktrf          0.0016      0.000      4.016      0.000       0.001       0.002
#  smb           -0.0004      0.001     -0.648      0.518      -0.002       0.001
#  hml           -0.0020      0.001     -3.019      0.003      -0.003      -0.001
#  RMW           -0.0005      0.001     -0.650      0.517      -0.002       0.001
#  CMA            0.0009      0.001      0.934      0.351      -0.001       0.003
#  umd            0.0008      0.000      2.605      0.010       0.000       0.001
#  ==============================================================================
#  Omnibus:                        4.932   Durbin-Watson:                   2.042
#  Prob(Omnibus):                  0.085   Jarque-Bera (JB):                4.995
#  Skew:                           0.239   Prob(JB):                       0.0823
#  Kurtosis:                       3.545   Cond. No.                         6.43
#  ==============================================================================
#
#  Notes:
#  [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#  """,
#  <class 'statsmodels.iolib.summary.Summary'>
#  """
#                              OLS Regression Results
#  ==============================================================================
#  Dep. Variable:                HFRIFOF   R-squared:                       0.540
#  Model:                            OLS   Adj. R-squared:                  0.527
#  Method:                 Least Squares   F-statistic:                     43.16
#  Date:                Sun, 22 Oct 2023   Prob (F-statistic):           1.12e-34
#  Time:                        00:41:38   Log-Likelihood:                 749.21
#  No. Observations:                 228   AIC:                            -1484.
#  Df Residuals:                     221   BIC:                            -1460.
#  Df Model:                           6
#  Covariance Type:            nonrobust
#  ==============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
#  ------------------------------------------------------------------------------
#  const          0.0002      0.001      0.332      0.740      -0.001       0.001
#  mktrf          0.0024      0.000     12.937      0.000       0.002       0.003
#  smb            0.0006      0.000      2.136      0.034    4.32e-05       0.001
#  hml           -0.0003      0.000     -0.954      0.341      -0.001       0.000
#  RMW         2.423e-05      0.000      0.067      0.946      -0.001       0.001
#  CMA           -0.0004      0.000     -1.063      0.289      -0.001       0.000
#  umd            0.0005      0.000      3.715      0.000       0.000       0.001
#  ==============================================================================
#  Omnibus:                       36.374   Durbin-Watson:                   1.607
#  Prob(Omnibus):                  0.000   Jarque-Bera (JB):               81.418
#  Skew:                          -0.751   Prob(JB):                     2.09e-18
#  Kurtosis:                       5.513   Cond. No.                         6.43
#  ==============================================================================
#
#  Notes:
#  [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#  """,
#  <class 'statsmodels.iolib.summary.Summary'>
#  """
#                              OLS Regression Results
#  ==============================================================================
#  Dep. Variable:                   Date   R-squared:                       0.083
#  Model:                            OLS   Adj. R-squared:                  0.058
#  Method:                 Least Squares   F-statistic:                     3.327
#  Date:                Sun, 22 Oct 2023   Prob (F-statistic):            0.00371
#  Time:                        00:41:38   Log-Likelihood:                -1751.4
#  No. Observations:                 228   AIC:                             3517.
#  Df Residuals:                     221   BIC:                             3541.
#  Df Model:                           6
#  Covariance Type:            nonrobust
#  ==============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
#  ------------------------------------------------------------------------------
#  const        2.01e+05     37.325   5385.549      0.000    2.01e+05    2.01e+05
#  mktrf         21.4376     10.582      2.026      0.044       0.582      42.293
#  smb          -46.8676     15.155     -3.093      0.002     -76.734     -17.001
#  hml           -9.8204     17.054     -0.576      0.565     -43.431      23.790
#  RMW          -21.3551     20.808     -1.026      0.306     -62.363      19.653
#  CMA          -20.3181     24.202     -0.840      0.402     -68.015      27.379
#  umd            8.4759      8.348      1.015      0.311      -7.977      24.929
#  ==============================================================================
#  Omnibus:                       33.752   Durbin-Watson:                   0.174
#  Prob(Omnibus):                  0.000   Jarque-Bera (JB):                8.820
#  Skew:                           0.001   Prob(JB):                       0.0122
#  Kurtosis:                       2.036   Cond. No.                         6.43
#  ==============================================================================
#
#  Notes:
#  [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#  """]

# %% [markdown]
# ### Global Minimum Variance

# %%
# First we create dataframes based on the in sample period for each excel sheet
# Then we fill the NaN values with mean of the column

# %%
mutualfund_is = mutualfund_excess[(mutualfund_excess['Date']>=200101) & (mutualfund_excess['Date']<=201212)]
mutualfund_is.drop(columns='Date',inplace=True)
mutualfund_is = mutualfund_is.apply(lambda col: col.fillna(col.mean()),axis=0)
# Out:
# C:\Users\azzra\AppData\Local\Temp\ipykernel_16796\2542682244.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mutualfund_is.drop(columns='Date',inplace=True)

# %%
smartbeta_is = smartbeta_excess[(smartbeta_excess['Date']>=200101) & (smartbeta_excess['Date']<=201212)]
smartbeta_is.drop(columns='Date',inplace=True)
smartbeta_is = smartbeta_is.apply(lambda col: col.fillna(col.mean()),axis=0)
# Out:
# C:\Users\azzra\AppData\Local\Temp\ipykernel_16796\1198732335.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   smartbeta_is.drop(columns='Date',inplace=True)

# %%
hedgefund_is = hedgefund_excess[(hedgefund_excess['Date']>=200101) & (hedgefund_excess['Date']<=201212)]
hedgefund_is.drop(columns='Date',inplace=True)
hedgefund_is = hedgefund_is.apply(lambda col: col.fillna(col.mean()),axis=0)
# Out:
# C:\Users\azzra\AppData\Local\Temp\ipykernel_16796\1237126557.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hedgefund_is.drop(columns='Date',inplace=True)

# %%
# Citation of code below

# Author: Danny Chen
# Portfolio-Optimization
# Code version 13
# Type: Source Code
# Web address: https://github.com/zhuodannychen/Portfolio-Optimization

# %%
# Define a function to calculate optimal weight for GMV

def minimum_variance(ret,long=True):
    def find_port_variance(weights):
# First we calculate the portfolio std dev using the code below
        cov = ret.cov()
        port_std = np.sqrt(np.dot(weights.T, np.dot(cov, weights)) * 12)
        return port_std
    
# We then create a function that will be used in the constraint later
    def weight_cons(weights):
        return np.sum(weights) - 1

    # The bounds will be between 0 and 1 for the weights because there is no short selling
    if long == True:
        bounds_lim = [(0,1) for x in range(len(ret.columns))] # change to (-1, 1) if you want to short
    else:
        bounds_lim =[(-1,1) for x in range(len(ret.columns))]
    
    init = [1/len(ret.columns) for i in range(len(ret.columns))] # this is the guessed value for weights 
    constraint = {'type': 'eq', 'fun': weight_cons}

    optimal = minimize(fun=find_port_variance,
                       x0=init,
                       bounds=bounds_lim,
                       constraints=constraint,
                       method='SLSQP'
                       )

    return list(optimal['x'])

# %%
w_mutualfund_long = minimum_variance(mutualfund_is)
w_mutualfund_short = minimum_variance(mutualfund_is,False)

# %%
w_smartbeta_long = minimum_variance(smartbeta_is)
w_smartbeta_short = minimum_variance(smartbeta_is,False)

# %%
w_hedgefund_long = minimum_variance(hedgefund_is)
w_hedgefund_short = minimum_variance(hedgefund_is,False)

# %%
w_mutualfund_long
# Out:
# [0.29949151320234607,
#  0.0,
#  1.0462550964485118e-16,
#  0.0,
#  7.101524229780054e-17,
#  0.0479558908138033,
#  0.0,
#  1.7564075194265172e-17,
#  0.6525525959838507,
#  0.0]

# %%
def GMV(ret, weight):
    mean_stat = []
    std_dev = []
    sharpe_r = []
    # use a for loop to make sure each asset weight is being multiplied correctly
    # to its respective return and covariance
    
    for i in range(len(weight)):
        mu = np.mean(ret.iloc[:, i]) # parse through each column and find its mean
        Sh = np.cov(ret, rowvar=False, ddof=0) # compute covariance matris
        mean_stat.append((mu * weight[i]*12)) # append the annualized portfolio return to a list
        std_dev.append(np.sqrt(12) * np.sqrt(np.dot(weight[i], Sh.dot(weight[i])))) # append annualized std dev to list
        sharpe_r.append(np.sqrt(12) * (np.dot(weight[i], mu) / std_dev[i])) # append annualized sharpe ratio to list

    return (np.mean(mean_stat), np.mean(std_dev), np.mean(sharpe_r))

# %%
print(GMV(mutualfund_is,w_mutualfund_long))
print(GMV(mutualfund_is,w_mutualfund_short))
# Out:
# (0.00406569772891765, 0.019857540223004472, nan)
# (0.00246545421224417, 0.04907403607861935, -0.007847595321685684)
# C:\Users\azzra\AppData\Local\Temp\ipykernel_16796\2518181319.py:13: RuntimeWarning: invalid value encountered in divide
#   sharpe_r.append(np.sqrt(12) * (np.dot(weight[i], mu) / std_dev[i])) # append annualized sharpe ratio to list

# %%
print(GMV(smartbeta_is,w_smartbeta_long))
print(GMV(smartbeta_is,w_smartbeta_short))
# Out:
# (0.005676272781512471, 0.013320748644058302, nan)
# (0.0014891836591054658, 0.04632236143846503, -0.003217697142383077)
# C:\Users\azzra\AppData\Local\Temp\ipykernel_16796\2518181319.py:13: RuntimeWarning: invalid value encountered in divide
#   sharpe_r.append(np.sqrt(12) * (np.dot(weight[i], mu) / std_dev[i])) # append annualized sharpe ratio to list

# %%
print(GMV(hedgefund_is,w_hedgefund_long))
print(GMV(hedgefund_is,w_hedgefund_short))
# Out:
# (0.001607941464113893, 0.005260694067345394, nan)
# (0.0016207167064299355, 0.011412102857602665, -0.02884973117213247)
# C:\Users\azzra\AppData\Local\Temp\ipykernel_16796\2518181319.py:13: RuntimeWarning: invalid value encountered in divide
#   sharpe_r.append(np.sqrt(12) * (np.dot(weight[i], mu) / std_dev[i])) # append annualized sharpe ratio to list
